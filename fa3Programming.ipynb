# %%
name = input("Name: ")
age = int(input("Age: "))
course = input("Course: ")


print(name,", age", age,", course is", course,".")
# Out:
# Name: Lorendino
# Age: 89
# Course: CS 1
# Lorendino , age 89 , course is CS 1 .

# %%
score = int(input("Score: "))


if score >= 75:
    print("Pass")
else:
    print("Fail")
# Out:
# Score: 9
# Failed

# %%
name = input("Name: ")
score = int(input("Score: "))


if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
else:
  print("F")
# Out:
# Name: 89
# Score: 89
# B
